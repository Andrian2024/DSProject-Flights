# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %% [markdown]
# # Data Preparation
#
# - Removed categories in each column that had less than 1% representation in the data.
# - Addressed anomalies, including:
#   - Columns containing multiple airlines or airports.
#   - Misclassified airlines that were actually bus or train companies (before the CSV was created).
# - Categorized flight hours into morning, noon, evening, and night.
# - Converted the float column for baggage to integers.
# - Removed outliers using Tukey's method, focusing on entries with more than one outlier.
# - Removed unnecessary columns.
# - Created dummy variables to relevant columns.
# - Added a day of the week dummy (departure and return)

# %%
data=pd.read_csv('WorkDB-28.02.25.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179504 entries, 0 to 179503
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Origin                             179504 non-null  object
#  1   Destination                        179504 non-null  object
#  2   TTT                                179504 non-null  int64
#  3   LOS                                179504 non-null  int64
#  4   Departure Time                     179504 non-null  object
#  5   Departure Date                     179504 non-null  object
#  6   Arrival Time                       179504 non-null  object
#  7   Return Departure Time              179504 non-null  object
#  8   Return Date                        179504 non-null  object
#  9   Return Arrival Time                179504 non-null  object
#  10  Onward Departure Airport           179504 non-null  object
#  11  Onward Arrival Airport             179504 non-null  object
#  12  Return Departure Airport           179504 non-null  object
#  13  Return Arrival Airport             179504 non-null  object
#  14  Onward Airlines                    179504 non-null  object
#  15  Return Airlines                    179504 non-null  object
#  16  Onward Flight Connections          179504 non-null  int64
#  17  Onward Connection Duration(min)    179504 non-null  int64
#  18  Onward Flight Connection Airport   1825 non-null    object
#  19  Return Flight Connections          179504 non-null  int64
#  20  Return Connection Duration(min)    179504 non-null  int64
#  21  Return Flight Connection Airport   1847 non-null    object
#  22  Carry-ons                          179499 non-null  float64
#  23  Checked Bags                       179500 non-null  float64
#  24  Price(NIS)                         179504 non-null  int64
#  25  Snapshot Time                      179504 non-null  object
#  26  Site                               179504 non-null  object
#  27  Total Onward Flight Duration(min)  179504 non-null  int64
#  28  Total Return Flight Duration(min)  179504 non-null  int64
# dtypes: float64(2), int64(9), object(18)
# memory usage: 39.7+ MB

# %%
data.columns
# Out:
# Index(['Origin', 'Destination', 'TTT', 'LOS', 'Departure Time',
#        'Departure Date', 'Arrival Time', 'Return Departure Time',
#        'Return Date', 'Return Arrival Time', 'Onward Departure Airport',
#        'Onward Arrival Airport', 'Return Departure Airport',
#        'Return Arrival Airport', 'Onward Airlines', 'Return Airlines',
#        'Onward Flight Connections', 'Onward Connection Duration(min)',
#        'Onward Flight Connection Airport', 'Return Flight Connections',
#        'Return Connection Duration(min)', 'Return Flight Connection Airport',
#        'Carry-ons', 'Checked Bags', 'Price(NIS)', 'Snapshot Time', 'Site',
#        'Total Onward Flight Duration(min)',
#        'Total Return Flight Duration(min)'],
#       dtype='object')

# %%
data['Departure DateTime String']=(data['Departure Date']+' '+data['Departure Time'])
data['Return DateTime String']=(data['Return Date']+' '+data['Return Departure Time'])

# %%
data['Departure DateTime']=pd.to_datetime(data['Departure DateTime String'],format='%d/%m/%Y %H:%M')
data['Return DateTime']=pd.to_datetime(data['Return DateTime String'],format='%d/%m/%Y %H:%M')

# %%
#Mean Price if there are 2 x's with the same value 
plt.figure(figsize=(15, 6))
sns.lineplot(data=data,x='TTT',y='Price(NIS)')
plt.ylabel("Price(NIS)")
plt.title("Price By Data & Time")
plt.show()
# Out:
# c:\Users\andri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\andri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(x='TTT', y='Price(NIS)', hue='LOS', data=data,palette="tab10")

plt.title('Price(NIS) vs TTT for different LOS values')
plt.xlabel('TTT')
plt.ylabel('Price(NIS)')
plt.legend(title='LOS')
plt.show()
# Out:
# c:\Users\andri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\andri\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Data Preparation:**

# %%
data.columns
# Out:
# Index(['Origin', 'Destination', 'TTT', 'LOS', 'Departure Time',
#        'Departure Date', 'Arrival Time', 'Return Departure Time',
#        'Return Date', 'Return Arrival Time', 'Onward Departure Airport',
#        'Onward Arrival Airport', 'Return Departure Airport',
#        'Return Arrival Airport', 'Onward Airlines', 'Return Airlines',
#        'Onward Flight Connections', 'Onward Connection Duration(min)',
#        'Onward Flight Connection Airport', 'Return Flight Connections',
#        'Return Connection Duration(min)', 'Return Flight Connection Airport',
#        'Carry-ons', 'Checked Bags', 'Price(NIS)', 'Snapshot Time', 'Site',
#        'Total Onward Flight Duration(min)',
#        'Total Return Flight Duration(min)', 'Departure DateTime String',
#        'Return DateTime String', 'Departure DateTime', 'Return DateTime'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179504 entries, 0 to 179503
# Data columns (total 33 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Origin                             179504 non-null  object
#  1   Destination                        179504 non-null  object
#  2   TTT                                179504 non-null  int64
#  3   LOS                                179504 non-null  int64
#  4   Departure Time                     179504 non-null  object
#  5   Departure Date                     179504 non-null  object
#  6   Arrival Time                       179504 non-null  object
#  7   Return Departure Time              179504 non-null  object
#  8   Return Date                        179504 non-null  object
#  9   Return Arrival Time                179504 non-null  object
#  10  Onward Departure Airport           179504 non-null  object
#  11  Onward Arrival Airport             179504 non-null  object
#  12  Return Departure Airport           179504 non-null  object
#  13  Return Arrival Airport             179504 non-null  object
#  14  Onward Airlines                    179504 non-null  object
#  15  Return Airlines                    179504 non-null  object
#  16  Onward Flight Connections          179504 non-null  int64
#  17  Onward Connection Duration(min)    179504 non-null  int64
#  18  Onward Flight Connection Airport   1825 non-null    object
#  19  Return Flight Connections          179504 non-null  int64
#  20  Return Connection Duration(min)    179504 non-null  int64
#  21  Return Flight Connection Airport   1847 non-null    object
#  22  Carry-ons                          179499 non-null  float64
#  23  Checked Bags                       179500 non-null  float64
#  24  Price(NIS)                         179504 non-null  int64
#  25  Snapshot Time                      179504 non-null  object
#  26  Site                               179504 non-null  object
#  27  Total Onward Flight Duration(min)  179504 non-null  int64
#  28  Total Return Flight Duration(min)  179504 non-null  int64
#  29  Departure DateTime String          179504 non-null  object
#  30  Return DateTime String             179504 non-null  object
#  31  Departure DateTime                 179504 non-null  datetime64[ns]
#  32  Return DateTime                    179504 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(9), object(20)
# memory usage: 45.2+ MB

# %%
data['Onward Airlines'].unique()
# Out:
# array(['Air France', 'Transavia France', 'easyJet', 'Vueling', 'Ryanair',
#        'ITA Airways', 'Wizz Air', 'Iberia', 'Transavia France, Wizz Air',
#        'Vueling, Ryanair', 'Vueling, Wizz Air', 'Ryanair, ITA Airways',
#        'Ryanair, Wizz Air', 'Jet2', 'British Airways',
#        'ITA Airways, Ryanair', 'Wizz Air, Wizz Air', 'Ryanair, easyJet',
#        'Wizz Air, Ryanair', 'Aeroitalia, Ryanair',
#        'Scandinavian Airlines', 'ITA Airways, Wizz Air', 'Eurowings',
#        'Tunisair', 'Wizz Air, easyJet', 'Ryanair, Ryanair',
#        'Austrian Airlines', 'KLM', 'Norwegian, Ryanair', 'Lufthansa',
#        'Ryanair, Vueling', 'Vueling, Transavia France',
#        'easyJet, Eurowings', 'Vueling, easyJet', 'Wizz Air, Air Albania',
#        'Ryanair, Aeroitalia', 'easyJet, ITA Airways', 'easyJet, Volotea',
#        'easyJet, Wizz Air', 'KM Malta Airlines', 'Wizz Air, Aeroitalia',
#        'Norwegian', 'SWISS'], dtype=object)

# %%
print(data['Onward Airlines'].str.contains(',').sum())
print(data['Return Airlines'].str.contains(',').sum())
print(data['Onward Flight Connection Airport'].str.contains(',').sum())
print(data['Return Flight Connection Airport'].str.contains(',').sum())
print(data['Onward Flight Connection Airport'].str.contains('-').sum())
print(data['Return Flight Connection Airport'].str.contains('-').sum())
# Out:
# 229
# 272
# 1
# 0
# 5
# 2

# %%
data['Onward Airlines'] = data['Onward Airlines'].str.split(',').str[0]
data['Return Airlines'] = data['Return Airlines'].str.split(',').str[0]
data['Onward Flight Connection Airport'] = data['Onward Flight Connection Airport'].str.split(',').str[0]
data['Onward Flight Connection Airport'] = data['Onward Flight Connection Airport'].str.split('-').str[0]
data['Return Flight Connection Airport'] = data['Return Flight Connection Airport'].str.split('-').str[0]

# %%
print(data['Onward Airlines'].str.contains(',').sum())
print(data['Return Airlines'].str.contains(',').sum())
print(data['Onward Flight Connection Airport'].str.contains(',').sum())
print(data['Return Flight Connection Airport'].str.contains(',').sum())
print(data['Onward Flight Connection Airport'].str.contains('-').sum())
print(data['Return Flight Connection Airport'].str.contains('-').sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %%
#check for data with less than 1% 
for category in data.columns:
    category_counts = data[category].value_counts(normalize=True)
    rare_categories = category_counts[category_counts < 0.01]
    print(f"Rare categories in '{category}':")
    print(rare_categories)
    print()
# Out:
# Rare categories in 'Origin':
# Series([], Name: proportion, dtype: float64)
#
# Rare categories in 'Destination':
# Series([], Name: proportion, dtype: float64)
#
# Rare categories in 'TTT':
# Series([], Name: proportion, dtype: float64)
#
# Rare categories in 'LOS':
# Series([], Name: proportion, dtype: float64)
#
# Rare categories in 'Departure Time':
# Departure Time
# 8:10     0.009732
# 18:25    0.009643
# 16:30    0.009498
# 10:00    0.009437
# 19:35    0.009415
#            ...
# 19:30    0.000022
# 19:10    0.000017
# 7:45     0.000006
# 22:30    0.000006
# 21:50    0.000006
# Name: proportion, Length: 166, dtype: float64
#
# Rare categories in 'Departure Date':
# Series([], Name: proportion, dtype: float64)
#
# Rare categories in 'Arrival Time':
# Arrival Time
# 18:25      0.009855
# 19:05      0.009426
# 16:05      0.009365
# 20:05      0.009192
# 12:40      0.009147
#              ...
# 15:10+1    0.000006
# 9:05       0.000006
# 0:50       0.000006
# 23:20      0.000006
# 07:10+1    0.000006
# Name: proportion, Length: 199, dtype: float64
#
# Rare categories in 'Return Departure Time':
# Return Departure Time
# 16:50    0.009849
# 20:20    0.009844
# 19:35    0.009543
# 16:30    0.009526
# 8:15     0.009476
#            ...
# 9:35     0.000111
# 20:05    0.000106
# 22:15    0.000084
# 22:00    0.000072
# 12:15    0.000045
# Name: proportion, Length: 173, dtype: float64
#
# Rare categories in 'Return Date':
# Return Date
# 2/3/2025    0.007186
# 4/4/2025    0.006379
# Name: proportion, dtype: float64
#
# Rare categories in 'Return Arrival Time':
# Return Arrival Time
# 13:50      0.009877
# 19:25      0.009833
# 18:25      0.009415
# 19:05      0.009136
# 12:35      0.009047
#              ...
# 23:59      0.000011
# 08:15+1    0.000006
# 13:50+1    0.000006
# 01:30+1    0.000006
# 22:15+1    0.000006
# Name: proportion, Length: 209, dtype: float64
#
# Rare categories in 'Onward Departure Airport':
# Onward Departure Airport
# SEN    0.003499
# LCY    0.001036
# Name: proportion, dtype: float64
#
# Rare categories in 'Onward Arrival Airport':
# Onward Arrival Airport
# SEN    0.002852
# LCY    0.001543
# Name: proportion, dtype: float64
#
# Rare categories in 'Return Departure Airport':
# Return Departure Airport
# SEN    0.003755
# LCY    0.000941
# SOU    0.000033
# Name: proportion, dtype: float64
#
# Rare categories in 'Return Arrival Airport':
# Return Arrival Airport
# SEN    0.004551
# LCY    0.001777
# SOU    0.000033
# Name: proportion, dtype: float64
#
# Rare categories in 'Onward Airlines':
# Onward Airlines
# Iberia                   0.002535
# Scandinavian Airlines    0.000646
# Eurowings                0.000189
# Tunisair                 0.000111
# Lufthansa                0.000056
# KLM                      0.000039
# Norwegian                0.000039
# KM Malta Airlines        0.000028
# Aeroitalia               0.000017
# Austrian Airlines        0.000006
# SWISS                    0.000006
# Name: proportion, dtype: float64
#
# Rare categories in 'Return Airlines':
# Return Airlines
# Iberia                   0.002568
# Scandinavian Airlines    0.000251
# Tunisair                 0.000150
# Eurowings                0.000084
# Lufthansa                0.000056
# KM Malta Airlines        0.000056
# Volotea                  0.000028
# Austrian Airlines        0.000006
# KLM                      0.000006
# Aeroitalia               0.000006
# Norwegian                0.000006
# Name: proportion, dtype: float64
#
# Rare categories in 'Onward Flight Connections':
# Onward Flight Connections
# 2    0.000011
# Name: proportion, dtype: float64
#
# Rare categories in 'Onward Connection Duration(min)':
# Onward Connection Duration(min)
# 50      0.001677
# 95      0.000975
# 55      0.000930
# 65      0.000674
# 115     0.000618
#           ...
# 1870    0.000006
# 220     0.000006
# 295     0.000006
# 250     0.000006
# 400     0.000006
# Name: proportion, Length: 75, dtype: float64
#
# Rare categories in 'Onward Flight Connection Airport':
# Onward Flight Connection Airport
# BLQ    0.009315
# MRS    0.009315
# SJJ    0.008767
# MAD    0.008767
# KRK    0.008219
# CTA    0.008219
# BRI    0.007671
# KTW    0.006027
# HHN    0.004932
# MUC    0.004384
# PMO    0.004384
# ALC    0.003836
# TLS    0.003836
# AMS    0.003836
# IBZ    0.003836
# CDG    0.003288
# CAG    0.002740
# MLA    0.002740
# BCM    0.002740
# STN    0.002740
# MXP    0.002740
# BTS    0.001644
# IAS    0.001644
# DUS    0.001644
# SUF    0.001644
# GVA    0.001644
# TRN    0.001096
# STR    0.001096
# NTE    0.001096
# NAP    0.001096
# GDN    0.001096
# FRA    0.001096
# DUB    0.000548
# EIN    0.000548
# SCV    0.000548
# ZRH    0.000548
# Name: proportion, dtype: float64
#
# Rare categories in 'Return Flight Connections':
# Series([], Name: proportion, dtype: float64)
#
# Rare categories in 'Return Connection Duration(min)':
# Return Connection Duration(min)
# 55     0.001309
# 50     0.001220
# 65     0.000969
# 95     0.000836
# 115    0.000591
#          ...
# 205    0.000006
# 300    0.000006
# 765    0.000006
# 315    0.000006
# 640    0.000006
# Name: proportion, Length: 70, dtype: float64
#
# Rare categories in 'Return Flight Connection Airport':
# Return Flight Connection Airport
# GOA    0.009204
# ZAG    0.008663
# BUD    0.008121
# IBZ    0.007580
# STR    0.006497
# PMO    0.005414
# GVA    0.005414
# MLA    0.005414
# SJJ    0.005414
# VIE    0.004331
# CTA    0.003790
# BLQ    0.003790
# TLS    0.003790
# FRA    0.003249
# CDG    0.003249
# SXB    0.002707
# BCM    0.002166
# MAD    0.002166
# MUC    0.002166
# BRI    0.002166
# IAS    0.002166
# MXP    0.002166
# HAM    0.001624
# FMM    0.001624
# GDN    0.001624
# POZ    0.001624
# MAN    0.001624
# SUF    0.001083
# MPL    0.001083
# TRN    0.001083
# HHN    0.000541
# NTE    0.000541
# BTS    0.000541
# ALC    0.000541
# AMS    0.000541
# BSL    0.000541
# BER    0.000541
# ORK    0.000541
# Name: proportion, dtype: float64
#
# Rare categories in 'Carry-ons':
# Series([], Name: proportion, dtype: float64)
#
# Rare categories in 'Checked Bags':
# Checked Bags
# 2.0    0.000345
# Name: proportion, dtype: float64
#
# Rare categories in 'Price(NIS)':
# Price(NIS)
# 289     0.005187
# 474     0.004886
# 292     0.004847
# 570     0.004730
# 459     0.004657
#           ...
# 1201    0.000006
# 1537    0.000006
# 1812    0.000006
# 2001    0.000006
# 2224    0.000006
# Name: proportion, Length: 1617, dtype: float64
#
# Rare categories in 'Snapshot Time':
# Series([], Name: proportion, dtype: float64)
#
# Rare categories in 'Site':
# Series([], Name: proportion, dtype: float64)
#
# Rare categories in 'Total Onward Flight Duration(min)':
# Total Onward Flight Duration(min)
# 85     0.007888
# 175    0.002763
# 60     0.001532
# 180    0.001454
# 205    0.000841
#          ...
# 485    0.000006
# 505    0.000006
# 560    0.000006
# 445    0.000006
# 655    0.000006
# Name: proportion, Length: 90, dtype: float64
#
# Rare categories in 'Total Return Flight Duration(min)':
# Total Return Flight Duration(min)
# 85      0.008423
# 95      0.002390
# 175     0.002240
# 60      0.001838
# 180     0.001382
#           ...
# 1525    0.000006
# 700     0.000006
# 200     0.000006
# 1600    0.000006
# 505     0.000006
# Name: proportion, Length: 89, dtype: float64
#
# Rare categories in 'Departure DateTime String':
# Departure DateTime String
# 16/03/2025 7:00     0.002072
# 23/03/2025 7:00     0.002011
# 2/3/2025 6:00       0.001916
# 2/3/2025 16:00      0.001883
# 23/03/2025 16:00    0.001844
#                       ...
# 4/3/2025 17:05      0.000006
# 26/03/2025 8:45     0.000006
# 26/03/2025 11:10    0.000006
# 5/3/2025 15:40      0.000006
# 17/03/2025 22:40    0.000006
# Name: proportion, Length: 2508, dtype: float64
#
# Rare categories in 'Return DateTime String':
# Return DateTime String
# 16/03/2025 7:00     0.002167
# 23/03/2025 16:00    0.001961
# 23/03/2025 7:00     0.001894
# 10/3/2025 6:00      0.001877
# 26/03/2025 16:10    0.001699
#                       ...
# 18/03/2025 16:20    0.000006
# 18/03/2025 15:45    0.000006
# 26/03/2025 10:45    0.000006
# 29/03/2025 19:00    0.000006
# 4/3/2025 7:55       0.000006
# Name: proportion, Length: 2919, dtype: float64
#
# Rare categories in 'Departure DateTime':
# Departure DateTime
# 2025-03-16 07:00:00    0.002072
# 2025-03-23 07:00:00    0.002011
# 2025-03-02 06:00:00    0.001916
# 2025-03-02 16:00:00    0.001883
# 2025-03-23 16:00:00    0.001844
#                          ...
# 2025-03-04 17:05:00    0.000006
# 2025-03-26 08:45:00    0.000006
# 2025-03-26 11:10:00    0.000006
# 2025-03-05 15:40:00    0.000006
# 2025-03-17 22:40:00    0.000006
# Name: proportion, Length: 2508, dtype: float64
#
# Rare categories in 'Return DateTime':
# Return DateTime
# 2025-03-16 07:00:00    0.002167
# 2025-03-23 16:00:00    0.001961
# 2025-03-23 07:00:00    0.001894
# 2025-03-10 06:00:00    0.001877
# 2025-03-26 16:10:00    0.001699
#                          ...
# 2025-03-18 16:20:00    0.000006
# 2025-03-18 15:45:00    0.000006
# 2025-03-26 10:45:00    0.000006
# 2025-03-29 19:00:00    0.000006
# 2025-03-04 07:55:00    0.000006
# Name: proportion, Length: 2919, dtype: float64

# %%
data = data[~data['Onward Departure Airport'].str.contains('SEN')]
data = data[~data['Onward Departure Airport'].str.contains('LCY')]
data = data[~data['Onward Arrival Airport'].str.contains('SEN')]
data = data[~data['Onward Arrival Airport'].str.contains('LCY')]
data = data[~data['Return Departure Airport'].str.contains('SEN')]
data = data[~data['Return Departure Airport'].str.contains('LCY')]
data = data[~data['Return Departure Airport'].str.contains('SOU')]
data = data[~data['Return Arrival Airport'].str.contains('SEN')]
data = data[~data['Return Arrival Airport'].str.contains('LCY')]
data = data[~data['Return Arrival Airport'].str.contains('SOU')]
data = data[~data['Onward Airlines'].str.contains('Iberia')]
data = data[~data['Onward Airlines'].str.contains('Scandinavian Airlines')]
data = data[~data['Onward Airlines'].str.contains('Eurowings')]
data = data[~data['Onward Airlines'].str.contains('Tunisair')]
data = data[~data['Onward Airlines'].str.contains('Lufthansa')]
data = data[~data['Onward Airlines'].str.contains('KLM')]
data = data[~data['Onward Airlines'].str.contains('Norwegian')]
data = data[~data['Onward Airlines'].str.contains('KM Malta Airlines')]
data = data[~data['Onward Airlines'].str.contains('Aeroitalia')]
data = data[~data['Onward Airlines'].str.contains('Austrian Airlines')]
data = data[~data['Onward Airlines'].str.contains('SWISS')]

data = data[~data['Return Airlines'].str.contains('Iberia')]
data = data[~data['Return Airlines'].str.contains('Scandinavian Airlines')]
data = data[~data['Return Airlines'].str.contains('Eurowings')]
data = data[~data['Return Airlines'].str.contains('Tunisair')]
data = data[~data['Return Airlines'].str.contains('Lufthansa')]
data = data[~data['Return Airlines'].str.contains('KLM')]
data = data[~data['Return Airlines'].str.contains('Norwegian')]
data = data[~data['Return Airlines'].str.contains('KM Malta Airlines')]
data = data[~data['Return Airlines'].str.contains('Aeroitalia')]
data = data[~data['Return Airlines'].str.contains('Austrian Airlines')]
data = data[~data['Return Airlines'].str.contains('SWISS')]
data = data[~data['Return Airlines'].str.contains('Volotea')]

# %%
data['Checked Bags'].fillna(0,inplace=True)
data['Checked Bags'] = data['Checked Bags'].astype(int)
data['Carry-ons'].fillna(0,inplace=True)
data['Carry-ons'] = data['Carry-ons'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 174969 entries, 0 to 179503
# Data columns (total 33 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Origin                             174969 non-null  object
#  1   Destination                        174969 non-null  object
#  2   TTT                                174969 non-null  int64
#  3   LOS                                174969 non-null  int64
#  4   Departure Time                     174969 non-null  object
#  5   Departure Date                     174969 non-null  object
#  6   Arrival Time                       174969 non-null  object
#  7   Return Departure Time              174969 non-null  object
#  8   Return Date                        174969 non-null  object
#  9   Return Arrival Time                174969 non-null  object
#  10  Onward Departure Airport           174969 non-null  object
#  11  Onward Arrival Airport             174969 non-null  object
#  12  Return Departure Airport           174969 non-null  object
#  13  Return Arrival Airport             174969 non-null  object
#  14  Onward Airlines                    174969 non-null  object
#  15  Return Airlines                    174969 non-null  object
#  16  Onward Flight Connections          174969 non-null  int64
#  17  Onward Connection Duration(min)    174969 non-null  int64
#  18  Onward Flight Connection Airport   1521 non-null    object
#  19  Return Flight Connections          174969 non-null  int64
#  20  Return Connection Duration(min)    174969 non-null  int64
#  21  Return Flight Connection Airport   1645 non-null    object
#  22  Carry-ons                          174969 non-null  int32
#  23  Checked Bags                       174969 non-null  int32
#  24  Price(NIS)                         174969 non-null  int64
#  25  Snapshot Time                      174969 non-null  object
#  26  Site                               174969 non-null  object
#  27  Total Onward Flight Duration(min)  174969 non-null  int64
#  28  Total Return Flight Duration(min)  174969 non-null  int64
#  29  Departure DateTime String          174969 non-null  object
#  30  Return DateTime String             174969 non-null  object
#  31  Departure DateTime                 174969 non-null  datetime64[ns]
#  32  Return DateTime                    174969 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int32(2), int64(9), object(20)
# memory usage: 44.1+ MB

# %%
#turn Hour to int
data['Departure Hour']=data['Departure Time'].str.split(':').str[0].astype(int)
data['Arrival Hour']=data['Arrival Time'].str.split(':').str[0].astype(int)
data['Return Departure Hour']=data['Return Departure Time'].str.split(':').str[0].astype(int)
data['Return Arrival Hour']=data['Return Arrival Time'].str.split(':').str[0].astype(int)

def categorize_time(time):
    if 0 <= time < 6:
        return 'Night'
    elif 6 <= time < 12:
        return 'Morning'
    elif 12 <= time < 18:
        return 'Noon'
    else:
        return 'Evening'

data['Onward Departure Time Of Day'] = data['Departure Hour'].apply(categorize_time)
data['Onward Arrival Time Of Day'] = data['Arrival Hour'].apply(categorize_time)
data['Return Departure Time Of Day'] = data['Return Departure Hour'].apply(categorize_time)
data['Return Arrival Time Of Day'] = data['Return Arrival Hour'].apply(categorize_time)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 174969 entries, 0 to 179503
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Origin                             174969 non-null  object
#  1   Destination                        174969 non-null  object
#  2   TTT                                174969 non-null  int64
#  3   LOS                                174969 non-null  int64
#  4   Departure Time                     174969 non-null  object
#  5   Departure Date                     174969 non-null  object
#  6   Arrival Time                       174969 non-null  object
#  7   Return Departure Time              174969 non-null  object
#  8   Return Date                        174969 non-null  object
#  9   Return Arrival Time                174969 non-null  object
#  10  Onward Departure Airport           174969 non-null  object
#  11  Onward Arrival Airport             174969 non-null  object
#  12  Return Departure Airport           174969 non-null  object
#  13  Return Arrival Airport             174969 non-null  object
#  14  Onward Airlines                    174969 non-null  object
#  15  Return Airlines                    174969 non-null  object
#  16  Onward Flight Connections          174969 non-null  int64
#  17  Onward Connection Duration(min)    174969 non-null  int64
#  18  Onward Flight Connection Airport   1521 non-null    object
#  19  Return Flight Connections          174969 non-null  int64
#  20  Return Connection Duration(min)    174969 non-null  int64
#  21  Return Flight Connection Airport   1645 non-null    object
#  22  Carry-ons                          174969 non-null  int32
#  23  Checked Bags                       174969 non-null  int32
#  24  Price(NIS)                         174969 non-null  int64
#  25  Snapshot Time                      174969 non-null  object
#  26  Site                               174969 non-null  object
#  27  Total Onward Flight Duration(min)  174969 non-null  int64
#  28  Total Return Flight Duration(min)  174969 non-null  int64
#  29  Departure DateTime String          174969 non-null  object
#  30  Return DateTime String             174969 non-null  object
#  31  Departure DateTime                 174969 non-null  datetime64[ns]
#  32  Return DateTime                    174969 non-null  datetime64[ns]
#  33  Departure Hour                     174969 non-null  int32
#  34  Arrival Hour                       174969 non-null  int32
#  35  Return Departure Hour              174969 non-null  int32
#  36  Return Arrival Hour                174969 non-null  int32
#  37  Onward Departure Time Of Day       174969 non-null  object
#  38  Onward Arrival Time Of Day         174969 non-null  object
#  39  Return Departure Time Of Day       174969 non-null  object
#  40  Return Arrival Time Of Day         174969 non-null  object
# dtypes: datetime64[ns](2), int32(6), int64(9), object(24)
# memory usage: 52.1+ MB

# %%
# Function to identify outliers using Tukey's method
def is_outlier(column):
    q1 = column.quantile(0.25)
    q3 = column.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return (column < lower_bound) | (column > upper_bound)

# Identify outliers for each numeric column
numeric_columns = data.select_dtypes(include=['int64', 'int32', 'float64']).columns
outlier_flags = data[numeric_columns].apply(is_outlier)

# Count the number of outlier features for each row
data['outlier_count'] = outlier_flags.sum(axis=1)

# Print the rows and their corresponding outlier features
outlier_details = outlier_flags[data['outlier_count'] >= 2]
print("Rows to be removed and their corresponding outlier features:")
print(outlier_details[outlier_details.any(axis=1)])

# Remove rows with outliers in 2 or more features
rows_before = data.shape[0]
data_filtered = data[data['outlier_count'] < 3]
rows_after = data_filtered.shape[0]

# Drop the 'outlier_count' column as it's no longer needed
data_filtered = data_filtered.drop(columns=['outlier_count'])

print(f"\nTotal rows removed: {rows_before - rows_after}")
# Out:
# Rows to be removed and their corresponding outlier features:
#           TTT    LOS  Onward Flight Connections  \
# 0       False  False                      False
# 1       False  False                      False
# 2       False  False                      False
# 3       False  False                      False
# 4       False  False                      False
# ...       ...    ...                        ...
# 179104  False  False                      False
# 179107  False  False                       True
# 179111  False  False                      False
# 179112  False  False                      False
# 179114  False  False                      False
#
#         Onward Connection Duration(min)  Return Flight Connections  \
# 0                                 False                      False
# 1                                 False                       True
# 2                                 False                      False
# 3                                 False                      False
# 4                                 False                      False
# ...                                 ...                        ...
# 179104                            False                       True
# 179107                             True                      False
# 179111                            False                       True
# 179112                            False                       True
# 179114                            False                       True
#
#         Return Connection Duration(min)  Carry-ons  Checked Bags  Price(NIS)  \
# 0                                 False       True         False        True
# 1                                  True       True         False        True
# 2                                 False       True         False        True
# 3                                 False       True         False        True
# 4                                 False       True         False        True
# ...                                 ...        ...           ...         ...
# 179104                             True      False         False       False
# 179107                            False      False         False       False
# 179111                             True      False         False       False
# 179112                             True      False         False       False
# 179114                             True      False          True       False
#
#         Total Onward Flight Duration(min)  Total Return Flight Duration(min)  \
# 0                                   False                              False
# 1                                   False                               True
# 2                                   False                              False
# 3                                   False                              False
# 4                                   False                              False
# ...                                   ...                                ...
# 179104                              False                               True
# 179107                               True                              False
# 179111                              False                               True
# 179112                              False                               True
# 179114                              False                               True
#
#         Departure Hour  Arrival Hour  Return Departure Hour  \
# 0                False         False                  False
# 1                False         False                  False
# 2                False         False                  False
# 3                False         False                  False
# 4                False         False                  False
# ...                ...           ...                    ...
# 179104           False         False                  False
# 179107           False         False                  False
# 179111           False         False                  False
# 179112           False         False                  False
# 179114           False         False                  False
#
#         Return Arrival Hour
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 179104                False
# 179107                False
# 179111                False
# 179112                False
# 179114                False
#
# [6269 rows x 15 columns]
#
# Total rows removed: 3179

# %%
print(data.shape)
print(data_filtered.shape)
# Out:
# (174969, 42)
# (171790, 41)

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 171790 entries, 0 to 179503
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Origin                             171790 non-null  object
#  1   Destination                        171790 non-null  object
#  2   TTT                                171790 non-null  int64
#  3   LOS                                171790 non-null  int64
#  4   Departure Time                     171790 non-null  object
#  5   Departure Date                     171790 non-null  object
#  6   Arrival Time                       171790 non-null  object
#  7   Return Departure Time              171790 non-null  object
#  8   Return Date                        171790 non-null  object
#  9   Return Arrival Time                171790 non-null  object
#  10  Onward Departure Airport           171790 non-null  object
#  11  Onward Arrival Airport             171790 non-null  object
#  12  Return Departure Airport           171790 non-null  object
#  13  Return Arrival Airport             171790 non-null  object
#  14  Onward Airlines                    171790 non-null  object
#  15  Return Airlines                    171790 non-null  object
#  16  Onward Flight Connections          171790 non-null  int64
#  17  Onward Connection Duration(min)    171790 non-null  int64
#  18  Onward Flight Connection Airport   17 non-null      object
#  19  Return Flight Connections          171790 non-null  int64
#  20  Return Connection Duration(min)    171790 non-null  int64
#  21  Return Flight Connection Airport   18 non-null      object
#  22  Carry-ons                          171790 non-null  int32
#  23  Checked Bags                       171790 non-null  int32
#  24  Price(NIS)                         171790 non-null  int64
#  25  Snapshot Time                      171790 non-null  object
#  26  Site                               171790 non-null  object
#  27  Total Onward Flight Duration(min)  171790 non-null  int64
#  28  Total Return Flight Duration(min)  171790 non-null  int64
#  29  Departure DateTime String          171790 non-null  object
#  30  Return DateTime String             171790 non-null  object
#  31  Departure DateTime                 171790 non-null  datetime64[ns]
#  32  Return DateTime                    171790 non-null  datetime64[ns]
#  33  Departure Hour                     171790 non-null  int32
#  34  Arrival Hour                       171790 non-null  int32
#  35  Return Departure Hour              171790 non-null  int32
#  36  Return Arrival Hour                171790 non-null  int32
#  37  Onward Departure Time Of Day       171790 non-null  object
#  38  Onward Arrival Time Of Day         171790 non-null  object
#  39  Return Departure Time Of Day       171790 non-null  object
#  40  Return Arrival Time Of Day         171790 non-null  object
# dtypes: datetime64[ns](2), int32(6), int64(9), object(24)
# memory usage: 51.1+ MB

# %%
data_filtered['Day Of Week Departure']=data['Departure DateTime'].dt.strftime('%A')
data_filtered['Day Of Week Return']=data['Return DateTime'].dt.strftime('%A')

# %%
columns_to_drop = ['Origin', 'Destination','Departure Time','Departure Date','Arrival Time','Return Departure Time','Return Date','Return Arrival Time','Onward Flight Connection Airport','Return Flight Connection Airport'
,'Snapshot Time','Departure DateTime String','Departure DateTime','Departure Hour','Arrival Hour','Return Departure Hour','Return Arrival Hour','Return DateTime','Return DateTime String']
data_filtered=data_filtered.drop(columns=columns_to_drop)

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 171790 entries, 0 to 179503
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   TTT                                171790 non-null  int64
#  1   LOS                                171790 non-null  int64
#  2   Onward Departure Airport           171790 non-null  object
#  3   Onward Arrival Airport             171790 non-null  object
#  4   Return Departure Airport           171790 non-null  object
#  5   Return Arrival Airport             171790 non-null  object
#  6   Onward Airlines                    171790 non-null  object
#  7   Return Airlines                    171790 non-null  object
#  8   Onward Flight Connections          171790 non-null  int64
#  9   Onward Connection Duration(min)    171790 non-null  int64
#  10  Return Flight Connections          171790 non-null  int64
#  11  Return Connection Duration(min)    171790 non-null  int64
#  12  Carry-ons                          171790 non-null  int32
#  13  Checked Bags                       171790 non-null  int32
#  14  Price(NIS)                         171790 non-null  int64
#  15  Site                               171790 non-null  object
#  16  Total Onward Flight Duration(min)  171790 non-null  int64
#  17  Total Return Flight Duration(min)  171790 non-null  int64
#  18  Onward Departure Time Of Day       171790 non-null  object
#  19  Onward Arrival Time Of Day         171790 non-null  object
#  20  Return Departure Time Of Day       171790 non-null  object
#  21  Return Arrival Time Of Day         171790 non-null  object
#  22  Day Of Week Departure              171790 non-null  object
#  23  Day Of Week Return                 171790 non-null  object
# dtypes: int32(2), int64(9), object(13)
# memory usage: 31.5+ MB

# %%
data_filtered = pd.get_dummies(data_filtered, columns=['Onward Departure Airport', 'Onward Arrival Airport','Return Departure Airport','Return Arrival Airport','Onward Airlines','Return Airlines','Site','Onward Departure Time Of Day','Onward Arrival Time Of Day','Return Departure Time Of Day','Return Arrival Time Of Day','Day Of Week Departure','Day Of Week Return'],drop_first=True)

# %%
data_filtered.columns
# Out:
# Index(['TTT', 'LOS', 'Onward Flight Connections',
#        'Onward Connection Duration(min)', 'Return Flight Connections',
#        'Return Connection Duration(min)', 'Carry-ons', 'Checked Bags',
#        'Price(NIS)', 'Total Onward Flight Duration(min)',
#        'Total Return Flight Duration(min)', 'Onward Departure Airport_CDG',
#        'Onward Departure Airport_CIA', 'Onward Departure Airport_FCO',
#        'Onward Departure Airport_LGW', 'Onward Departure Airport_LHR',
#        'Onward Departure Airport_LTN', 'Onward Departure Airport_ORY',
#        'Onward Departure Airport_STN', 'Onward Arrival Airport_CDG',
#        'Onward Arrival Airport_CIA', 'Onward Arrival Airport_FCO',
#        'Onward Arrival Airport_LGW', 'Onward Arrival Airport_LHR',
#        'Onward Arrival Airport_LTN', 'Onward Arrival Airport_ORY',
#        'Onward Arrival Airport_STN', 'Return Departure Airport_CDG',
#        'Return Departure Airport_CIA', 'Return Departure Airport_FCO',
#        'Return Departure Airport_LGW', 'Return Departure Airport_LHR',
#        'Return Departure Airport_LTN', 'Return Departure Airport_ORY',
#        'Return Departure Airport_STN', 'Return Arrival Airport_CDG',
#        'Return Arrival Airport_CIA', 'Return Arrival Airport_FCO',
#        'Return Arrival Airport_LGW', 'Return Arrival Airport_LHR',
#        'Return Arrival Airport_LTN', 'Return Arrival Airport_ORY',
#        'Return Arrival Airport_STN', 'Onward Airlines_British Airways',
#        'Onward Airlines_ITA Airways', 'Onward Airlines_Jet2',
#        'Onward Airlines_Ryanair', 'Onward Airlines_Transavia France',
#        'Onward Airlines_Vueling', 'Onward Airlines_Wizz Air',
#        'Onward Airlines_easyJet', 'Return Airlines_British Airways',
#        'Return Airlines_ITA Airways', 'Return Airlines_Jet2',
#        'Return Airlines_Ryanair', 'Return Airlines_Transavia France',
#        'Return Airlines_Vueling', 'Return Airlines_Wizz Air',
#        'Return Airlines_easyJet', 'Site_Momondo',
#        'Onward Departure Time Of Day_Morning',
#        'Onward Departure Time Of Day_Night',
#        'Onward Departure Time Of Day_Noon',
#        'Onward Arrival Time Of Day_Morning',
#        'Onward Arrival Time Of Day_Night', 'Onward Arrival Time Of Day_Noon',
#        'Return Departure Time Of Day_Morning',
#        'Return Departure Time Of Day_Night',
#        'Return Departure Time Of Day_Noon',
#        'Return Arrival Time Of Day_Morning',
#        'Return Arrival Time Of Day_Night', 'Return Arrival Time Of Day_Noon',
#        'Day Of Week Departure_Monday', 'Day Of Week Departure_Saturday',
#        'Day Of Week Departure_Sunday', 'Day Of Week Departure_Thursday',
#        'Day Of Week Departure_Tuesday', 'Day Of Week Departure_Wednesday',
#        'Day Of Week Return_Monday', 'Day Of Week Return_Saturday',
#        'Day Of Week Return_Sunday', 'Day Of Week Return_Thursday',
#        'Day Of Week Return_Tuesday', 'Day Of Week Return_Wednesday'],
#       dtype='object')

# %% [markdown]
# # Gradient Boosting

# %%
"""from sklearn.preprocessing import StandardScaler
continuous_cols = [
    'TTT', 'LOS', 'Onward Connection Duration(min)', 'Return Connection Duration(min)', 
    'Total Onward Flight Duration(min)', 'Total Return Flight Duration(min)','Carry-ons','Checked Bags'
]
scaler = StandardScaler()
data_filtered[continuous_cols] = scaler.fit_transform(data_filtered[continuous_cols])
#NO NEED"""
# Out:
# "from sklearn.preprocessing import StandardScaler\ncontinuous_cols = [\n    'TTT', 'LOS', 'Onward Connection Duration(min)', 'Return Connection Duration(min)', \n    'Total Onward Flight Duration(min)', 'Total Return Flight Duration(min)','Carry-ons','Checked Bags'\n]\nscaler = StandardScaler()\ndata_filtered[continuous_cols] = scaler.fit_transform(data_filtered[continuous_cols])\n#NO NEED"

# %%
# Define X (features) and y (target variable)
X = data_filtered.drop(columns=['Price(NIS)'])  # All features except the target
y = data_filtered['Price(NIS)']  # Target variable

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(
    n_estimators=500,    # Number of trees (more trees = better learning but slower)
    learning_rate=0.05,  # Step size (lower = better generalization)
    max_depth=5,         # Depth of each tree (higher = more complex)
    subsample=0.8,       # Use 80% of data for each tree (prevents overfitting)
    random_state=42
)

# Train the model
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, max_depth=5, n_estimators=500,
#                           random_state=42, subsample=0.8)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Make predictions
y_pred = gbr.predict(X_test)

# Compute metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.4f}")  # Higher is better (1.0 = perfect prediction)
# Out:
# MAE: 62.03
# RMSE: 88.24
# R² Score: 0.8811

# %%
from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'n_estimators': [100, 300, 500, 700],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'subsample': [0.7, 0.8, 0.9]
}

grid_search = RandomizedSearchCV(GradientBoostingRegressor(), param_grid, n_iter=10, cv=3,verbose=2, scoring='r2', n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Best parameters: {'subsample': 0.9, 'n_estimators': 700, 'max_depth': 7, 'learning_rate': 0.1}

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(**grid_search.best_params_)

# Train the model
gbr.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=7, n_estimators=700, subsample=0.9)

# %%
y_pred = gbr.predict(X_test)

# Compute metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.4f}")  # Higher is better (1.0 = perfect prediction)
# Out:
# MAE: 34.14
# MSE: 2505.12
# RMSE: 50.05
# R² Score: 0.9617

# %%
importances = gbr.feature_importances_
feature_names = X_train.columns

# Sort features by importance
sorted_idx = np.argsort(importances)[::-1]
sorted_features = np.array(feature_names)[sorted_idx]
sorted_importances = importances[sorted_idx]

# Plot feature importance
plt.figure(figsize=(10, 6))
plt.barh(sorted_features[:10], sorted_importances[:10], color='skyblue')
plt.xlabel("Feature Importance Score")
plt.ylabel("Feature")
plt.title("Top 10 Most Important Features")
plt.gca().invert_yaxis()
plt.show()

# %%
# Residuals = Actual - Predicted
residuals = y_test - y_pred
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_pred, y=residuals, alpha=0.5)

plt.axhline(y=0, color='r', linestyle='--')  # Reference line at 0
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %% [markdown]
# # Conclusion:
# The GradientBoostingRegressor model with max_depth=7, n_estimators=700, and subsample=0.9 has demonstrated strong predictive performance, achieving an R² score of 0.9617, indicating that the model explains approximately 96.17% of the variance in flight prices. The relatively low MAE (34.14) and RMSE (50.05) further confirm that the model's predictions are precise, with minimal error.
#
# However, analyzing the residual plot reveals some signs of heteroscedasticity, as residuals tend to spread wider for higher predicted values. This suggests that the model might slightly struggle with extreme price predictions.
#
# The importance is interesting, as sunday, TTT, LOS and flight duration are the most influensial. but here too tehre is British Airlines as next in line, maybe it is because it is not low-cost company.
